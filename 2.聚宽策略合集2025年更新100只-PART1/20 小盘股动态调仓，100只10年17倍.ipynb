# %%
import numpy as np
import pandas as pd
import datetime as dt
import json

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
funds = [
    '159650.XSHE', # 国开ETF
    '511020.XSHG', # 活跃国债ETF
    '518880.XSHG', # 黄金ETF
    '513500.XSHG', # 标普500
    '513300.XSHG', # 纳指100
    ]

# %%
# report
for s in funds:
    print(s, get_security_info(s).display_name)
# Out:
# 159650.XSHE 国开ETF
# 511020.XSHG 活跃国债
# 518880.XSHG 黄金ETF
# 513500.XSHG 标普500
# 513300.XSHG 纳斯达克ETF

# %%
# save
write_file('funds', json.dumps(funds))
# Out:
# 75

# %%
# load
_funds = json.loads(read_file('funds'))
_funds
# Out:
# ['159650.XSHE', '511020.XSHG', '518880.XSHG', '513500.XSHG', '513300.XSHG']
